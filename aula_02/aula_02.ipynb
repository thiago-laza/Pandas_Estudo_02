# %%
import pandas as pd

# %%
url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
dados_co2 = pd.read_excel(url)

# %%
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita = pd.read_excel(url, sheet_name='emissoes_percapita')

# %%
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes = pd.read_excel(url, sheet_name='fontes')

# %%
fontes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02',usecols='A:D')

# %%
intervalo.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750    0.0
# 1  Afeganistão                AFG  1751    0.0
# 2  Afeganistão                AFG  1752    0.0
# 3  Afeganistão                AFG  1753    0.0
# 4  Afeganistão                AFG  1754    0.0

# %%
intervalo
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total
# 0      Afeganistão                AFG  1750  0.000000e+00
# 1      Afeganistão                AFG  1751  0.000000e+00
# 2      Afeganistão                AFG  1752  0.000000e+00
# 3      Afeganistão                AFG  1753  0.000000e+00
# 4      Afeganistão                AFG  1754  0.000000e+00
# ...            ...                ...   ...           ...
# 63099       Global                WLD  2017  3.609674e+10
# 63100       Global                WLD  2018  3.682651e+10
# 63101       Global                WLD  2019  3.708256e+10
# 63102       Global                WLD  2020  3.526409e+10
# 63103       Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalo_2 = pd.read_excel(url,sheet_name='emissoes_C02',usecols='A:D',nrows=10)

# %%
intervalo_2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
percapita.to_excel('co2_percapita.xlsx',index=False)

# %%
pd.read_excel('/home/laza/Dados/Alura/Pandas/c2_trabalhando_com_diferentes_formatos_arquivos/aula_02/co2_percapita.xlsx')
# Out:
#               País ISO 3166-1 alpha-3   Ano  \
# 0      Afeganistão                AFG  1750
# 1      Afeganistão                AFG  1751
# 2      Afeganistão                AFG  1752
# 3      Afeganistão                AFG  1753
# 4      Afeganistão                AFG  1754
# ...            ...                ...   ...
# 63099       Global                WLD  2017
# 63100       Global                WLD  2018
# 63101       Global                WLD  2019
# 63102       Global                WLD  2020
# 63103       Global                WLD  2021
#
#                                       Total             Carvão  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...                                     ...                ...
# 63099  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63100  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63101  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63102  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63103  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
#
#                     Oléo                Gás        Cimento  \
# 0                 [NONE]             [NONE]         [NONE]
# 1                 [NONE]             [NONE]         [NONE]
# 2                 [NONE]             [NONE]         [NONE]
# 3                 [NONE]             [NONE]         [NONE]
# 4                 [NONE]             [NONE]         [NONE]
# ...                  ...                ...            ...
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
#                    Queima   Outro  \
# 0                  [NONE]  [NONE]
# 1                  [NONE]  [NONE]
# 2                  [NONE]  [NONE]
# 3                  [NONE]  [NONE]
# 4                  [NONE]  [NONE]
# ...                   ...     ...
# 63099  CDIAC 2022 and GCP  [NONE]
# 63100  CDIAC 2022 and GCP  [NONE]
# 63101  CDIAC 2022 and GCP  [NONE]
# 63102  CDIAC 2022 and GCP  [NONE]
# 63103  CDIAC 2022 and GCP  [NONE]
#
#                                               Per Capita
# 0                                                 [NONE]
# 1                                                 [NONE]
# 2                                                 [NONE]
# 3                                                 [NONE]
# 4                                                 [NONE]
# ...                                                  ...
# 63099  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63100  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63101  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63102  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63103  CDIAC 2022, BP, Sum of countries, and UN popul...
#
# [63104 rows x 11 columns]

# %%
https://docs.google.com/spreadsheets/d/1HsnZFbWyaN1hOhBHhpnjuuYswzaeQZV8UUGtSZPaz1o/edit?usp=sharing

# %%
sheet_id = '1HsnZFbWyaN1hOhBHhpnjuuYswzaeQZV8UUGtSZPaz1o'

# %%
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=aut:csv&sheet'

# %%
dados_co2_sheets = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dados_co2_sheets = pd.read_csv(url)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:293, in CParserWrapper.read(self, nrows)
#     290     values = self._maybe_parse_dates(values, i, try_parse_dates=True)
#     291     arrays.append(values)
# --> 293 index = ensure_index_from_sequences(arrays)
#     295 if self.usecols is not None:
#     296     names = self._filter_usecols(names)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7590, in ensure_index_from_sequences(sequences, names)
#    7588     return Index(sequences[0], name=names)
#    7589 else:
# -> 7590     return MultiIndex.from_arrays(sequences, names=names)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/multi.py:533, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     530     if len(arrays[i]) != len(arrays[i - 1]):
#     531         raise ValueError("all arrays must be same length")
# --> 533 codes, levels = factorize_from_iterables(arrays)
#     534 if names is lib.no_default:
#     535     names = [getattr(arr, "name", None) for arr in arrays]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/categorical.py:3069, in factorize_from_iterables(iterables)
#    3065 if len(iterables) == 0:
#    3066     # For consistency, it should return two empty lists.
#    3067     return [], []
# -> 3069 codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    3070 return list(codes), list(categories)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/categorical.py:3069, in <genexpr>(.0)
#    3065 if len(iterables) == 0:
#    3066     # For consistency, it should return two empty lists.
#    3067     return [], []
# -> 3069 codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    3070 return list(codes), list(categories)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/categorical.py:3042, in factorize_from_iterable(values)
#    3037     codes = values.codes
#    3038 else:
#    3039     # The value of ordered is irrelevant since we don't use cat as such,
#    3040     # but only the resulting categories, the order of which is independent
#    3041     # from ordered. Set ordered to False as default. See GH #15457
# -> 3042     cat = Categorical(values, ordered=False)
#    3043     categories = cat.categories
#    3044     codes = cat.codes
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/categorical.py:473, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     466                 raise TypeError(
#     467                     "'values' is not ordered, please "
#     468                     "explicitly specify the categories order "
#     469                     "by passing in a categories argument."
#     470                 ) from err
#     472         # we're inferring from values
# --> 473         dtype = CategoricalDtype(categories, dtype.ordered)
#     475 elif isinstance(values.dtype, CategoricalDtype):
#     476     old_codes = extract_array(values)._codes
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/dtypes.py:221, in CategoricalDtype.__init__(self, categories, ordered)
#     220 def __init__(self, categories=None, ordered: Ordered = False) -> None:
# --> 221     self._finalize(categories, ordered, fastpath=False)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/dtypes.py:378, in CategoricalDtype._finalize(self, categories, ordered, fastpath)
#     375     self.validate_ordered(ordered)
#     377 if categories is not None:
# --> 378     categories = self.validate_categories(categories, fastpath=fastpath)
#     380 self._categories = categories
#     381 self._ordered = ordered
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/dtypes.py:572, in CategoricalDtype.validate_categories(categories, fastpath)
#     568     raise TypeError(
#     569         f"Parameter 'categories' must be list-like, was {repr(categories)}"
#     570     )
#     571 if not isinstance(categories, ABCIndex):
# --> 572     categories = Index._with_infer(categories, tupleize_cols=False)
#     574 if not fastpath:
#     575     if categories.hasnans:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:680, in Index._with_infer(cls, *args, **kwargs)
#     674 @classmethod
#     675 def _with_infer(cls, *args, **kwargs):
#     676     """
#     677     Constructor that uses the 1.0.x behavior inferring numeric dtypes
#     678     for ndarray[object] inputs.
#     679     """
# --> 680     result = cls(*args, **kwargs)
#     682     if result.dtype == _dtype_obj and not result._is_multi:
#     683         # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     684         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     685         # "ndarray[Any, Any]"
#     686         values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:565, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     562         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     564 try:
# --> 565     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     566 except ValueError as err:
#     567     if "index must be specified when data is not list-like" in str(err):
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/construction.py:581, in sanitize_array(data, index, dtype, copy, allow_2d)
#     577     data = construct_1d_arraylike_from_scalar(data, len(index), dtype)
#     579     return data
# --> 581 elif isinstance(data, ABCExtensionArray):
#     582     # it is already ensured above this is not a NumpyExtensionArray
#     583     # Until GH#49309 is fixed this check needs to come before the
#     584     #  ExtensionDtype check
#     585     if dtype is not None:
#     586         subarr = data.astype(dtype, copy=copy)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/generic.py:44, in create_pandas_abc_type.<locals>._instancecheck(cls, inst)
#      42 @classmethod  # type: ignore[misc]
#      43 def _instancecheck(cls, inst) -> bool:
# ---> 44     return _check(inst) and not isinstance(inst, type)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/generic.py:37, in create_pandas_abc_type.<locals>._check(inst)
#      36 def create_pandas_abc_type(name, attr, comp):
# ---> 37     def _check(inst) -> bool:
#      38         return getattr(inst, attr, "_typ") in comp
#      40     # https://github.com/python/mypy/issues/1006
#      41     # error: 'classmethod' used with a non-method
#
# KeyboardInterrupt:

# %% [markdown]
# ---
#
# Nessa aula, você aprendeu a:
#
# - Entender o que é uma planilha;
# - Realizar a leitura de um arquivo no formato XLSX;
# - Identificar páginas em uma planilha;
# - Fazer a leitura de páginas e intervalo específicos de uma planilha;
# - Ler apenas algumas linhas de uma planilha;
# - Escrever um arquivo no formato XLSX;
# - Importar dados provenientes do Google Planilhas.
